# %%
import pandas as pd

# %%
data = pd.read_csv("../data/all_links.csv")
data.info()
display(data.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51347 entries, 0 to 51346
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          51347 non-null  int64
#  1   title       51303 non-null  object
#  2   typeName    51347 non-null  object
#  3   statusName  51347 non-null  object
#  4   acceptDate  51347 non-null  object
#  5   classCode   51347 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 2.4+ MB
#       id                                              title  \
# 0  57457  Azərbaycan Respublikası Nazirlər Kabinetinin 2...
# 1  57458  Azərbaycan Respublikası Nazirlər Kabinetinin 2...
# 2  57435  “Respublika Qan Bankı” publik hüquqi şəxsin ya...
# 3  57436  İ.M.Məmmədovun 3-cü dərəcəli “Əmək” ordeni ilə...
# 4  57437  C.T.Əbdul-Qədirovun Oğuz Rayon İcra Hakimiyyət...
# 5  57438  E.D.Qurbanovun Oğuz Rayon İcra Hakimiyyətinin ...
# 6  57439  Azərbaycan Respublikası Prezidentinin 2018-ci ...
# ...

# %%
data["typeName"].unique()
# Out:
# array(['Nazirlər Kabinetinin qərarları',
#        'AZƏRBAYCAN RESPUBLİKASI PREZİDENTİNİN FƏRMANLARI',
#        'AZƏRBAYCAN RESPUBLİKASI PREZİDENTİNİN SƏRƏNCAMLARI',
#        'AZƏRBAYCAN RESPUBLİKASI MƏRKƏZİ SEÇKİ KOMİSSİYASININ QƏRARLARI, TƏLİMATLARI VƏ İZAHLARI',
#        'Nazirlər Kabinetinin təsdiq etdiyi qaydalar',
#        'Nazirlər Kabinetinin təsdiq etdiyi nümunələr',
#        'AZƏRBAYCAN RESPUBLİKASI NAZİRLƏR KABİNETİNİN SƏRƏNCAMLARI',
#        'Beynəlxalq hüquqi bəyannamələr',
#        'YERLİ ÖZÜNÜİDARƏ ORQANLARININ QƏRARLARI',
#        'Fövqəladə Hallar Nazirliyi', 'Kənd Təsərrüfatı Nazirliyi',
#        'Nazirlər Kabinetinin təsdiq etdiyi təsvirlər',
#        'Nazirlər Kabinetinin təsdiq etdiyi spesifikasiyalar',
#        'Nazirlər Kabinetinin təsdiq etdiyi siyahılar',
#        'Dövlət Statistika Komitəsi',
#        'Nazirlər Kabinetinin təsdiq etdiyi nizamnamələr',
#        'Nazirlər Kabinetinin yaratdığı zonalar',
# ...

# %%
data[data["typeName"] == "AZƏRBAYCAN RESPUBLİKASI PREZİDENTİNİN FƏRMANLARI"]
# Out:
#           id                                              title  \
# 2      57435  “Respublika Qan Bankı” publik hüquqi şəxsin ya...
# 6      57439  Azərbaycan Respublikası Prezidentinin 2018-ci ...
# 7      57440  “Dövlət qulluğu haqqında” Azərbaycan Respublik...
# 8      57443  “Şəhid adının əbədiləşdirilməsi və şəhid ailəl...
# 9      57446  “Mühasibat uçotu haqqında” Azərbaycan Respubli...
# ...      ...                                                ...
# 51328   6355  Ə. C. Qasımov yoldaşa "Azərbaycan SSR əməkdar ...
# 51329   6356  Ə. R. Topçiyev yoldaşın Azərbaycan SSR-in Fəxr...
# 51335   6353  M. M. Aşurov yoldaşın Azərbaycan SSR-in Fəxri ...
# 51336   6342  Azərbaycan SSR-in hərbi komissarlıqları tərəfi...
# 51339   6351  A. S. Manafova yoldaşın Azərbaycan SSR-in Fəxr...
#
#                                                typeName  statusName  \
# 2      AZƏRBAYCAN RESPUBLİKASI PREZİDENTİNİN FƏRMANLARI  Qüvvədədir
# ...
